# %%
# %load explore.py
"""
Script d'analyse exploratoire des données
Alternative au notebook pour une exécution rapide
"""
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Configuration
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

def load_data():
    """Charger les données"""
    print("📂 Chargement des données...")
    df = pd.read_csv('../data/car-details.csv')
    print(f"✅ Données chargées : {df.shape[0]} lignes, {df.shape[1]} colonnes")
    print(df.head())
    return df

def basic_info(df):
    """Informations de base"""
    print("\n" + "="*50)
    print("📊 INFORMATIONS GÉNÉRALES")
    print("="*50)
    print(f"\n📋 Colonnes : {df.columns.tolist()}")
    print(f"\n📏 Dimensions : {df.shape}")
    print(f"\n🔢 Types de données :")
    print(df.dtypes)
    print(f"\n❓ Valeurs manquantes :")
    print(df.isnull().sum())
    print(f"\n🔁 Doublons : {df.duplicated().sum()}")

def statistical_summary(df):
    """Résumé statistique"""
    print("\n" + "="*50)
    print("📈 STATISTIQUES DESCRIPTIVES")
    print("="*50)
    print(df.describe())
    
    if 'selling_price' in df.columns:
        print(f"\n💰 Prix :")
        print(f"  - Minimum : {df['selling_price'].min():,.2f}")
        print(f"  - Maximum : {df['selling_price'].max():,.2f}")
        print(f"  - Moyenne : {df['selling_price'].mean():,.2f}")
        print(f"  - Médiane : {df['selling_price'].median():,.2f}")

def categorical_analysis(df):
    """Analyse des variables catégorielles"""
    print("\n" + "="*50)
    print("🏷️  VARIABLES CATÉGORIELLES")
    print("="*50)
    
    categorical_cols = df.select_dtypes(include=['object']).columns
    
    for col in categorical_cols:
        print(f"\n📊 Distribution de '{col}' :")
        print(df[col].value_counts().head(10))
        print(f"   Nombre de valeurs uniques : {df[col].nunique()}")

def correlation_analysis(df):
    """Analyse des corrélations"""
    print("\n" + "="*50)
    print("🔗 CORRÉLATIONS")
    print("="*50)
    
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    
    if len(numeric_cols) > 1:
        print("\nMatrice de corrélation :")
        corr = df[numeric_cols].corr()
        print(corr)
        
        if 'selling_price' in corr.columns:
            print(f"\n💰 Corrélation avec le Prix :")
            price_corr = corr['selling_price'].sort_values(ascending=False)
            for feature, corr_value in price_corr.items():
                if feature != 'selling_price':
                    print(f"  - {feature}: {corr_value:.4f}")

def visualizations(df):
    """Créer des visualisations"""
    print("\n" + "="*50)
    print("📊 GÉNÉRATION DES VISUALISATIONS")
    print("="*50)
    
    # Créer un dossier pour les graphiques
    import os
    os.makedirs('visualizations', exist_ok=True)
    
    # 1. Distribution du prix
    if 'selling_price' in df.columns:
        plt.figure(figsize=(10, 6))
        plt.hist(df['selling_price'], bins=50, edgecolor='black', alpha=0.7)
        plt.xlabel('Prix')
        plt.ylabel('Fréquence')
        plt.title('Distribution des Prix')
        plt.savefig('visualizations/price_distribution.png', dpi=150, bbox_inches='tight')
        plt.close()
        print("✅ Graphique sauvegardé : price_distribution.png")
    
    # 2. Prix par marque (top 10)
    if 'selling_price' in df.columns and 'company' in df.columns:
        top_companies = df['company'].value_counts().head(10).index
        df_top = df[df['company'].isin(top_companies)]

        plt.figure(figsize=(12, 6))
        df_top.groupby('company')['selling_price'].mean().sort_values().plot(kind='barh')
        plt.xlabel('Prix Moyen')
        plt.ylabel('Marque')
        plt.title('Prix Moyen par Marque (Top 10)')
        plt.tight_layout()
        plt.savefig('visualizations/price_by_company.png', dpi=150, bbox_inches='tight')
        plt.close()
        print("✅ Graphique sauvegardé : price_by_company.png")
    
    # 3. Prix vs Kilométrage
    if 'selling_price' in df.columns and 'km_driven' in df.columns:
        plt.figure(figsize=(10, 6))
        plt.scatter(df['km_driven'], df['selling_price'], alpha=0.5)
        plt.xlabel('Kilométrage')
        plt.ylabel('Prix')
        plt.title('Prix vs Kilométrage')
        plt.savefig('visualizations/price_vs_kms.png', dpi=150, bbox_inches='tight')
        plt.close()
        print("✅ Graphique sauvegardé : price_vs_kms.png")
    
    # 4. Prix vs Année
    if 'selling_price' in df.columns and 'year' in df.columns:
        plt.figure(figsize=(10, 6))
        df.groupby('year')['selling_price'].mean().plot(kind='line', marker='o')
        plt.xlabel('Année')
        plt.ylabel('Prix Moyen')
        plt.title('Prix Moyen par Année')
        plt.grid(True, alpha=0.3)
        plt.savefig('visualizations/price_by_year.png', dpi=150, bbox_inches='tight')
        plt.close()
        print("✅ Graphique sauvegardé : price_by_year.png")
    
    # 5. Distribution du type de carburant
    if 'fuel' in df.columns:
        plt.figure(figsize=(8, 8))
        df['fuel'].value_counts().plot(kind='pie', autopct='%1.1f%%')
        plt.title('Distribution du Type de Carburant')
        plt.ylabel('')
        plt.savefig('visualizations/fuel_type_distribution.png', dpi=150, bbox_inches='tight')
        plt.close()
        print("✅ Graphique sauvegardé : fuel_type_distribution.png")
    
    print(f"\n📁 Tous les graphiques sont dans le dossier 'visualizations/'")

def main():
    """Fonction principale"""
    print("\n" + "="*50)
    print("🚗 ANALYSE EXPLORATOIRE - CarPriceML")
    print("="*50)
    
    # Charger les données
    df = load_data()
    
    # Analyses
    basic_info(df)
    statistical_summary(df)
    categorical_analysis(df)
    correlation_analysis(df)
    visualizations(df)
    
    print("\n" + "="*50)
    print("✅ ANALYSE TERMINÉE")
    print("="*50)

if __name__ == "__main__":
    main()
# Out:
# ==================================================
# 🚗 ANALYSE EXPLORATOIRE - CarPriceML
# ==================================================
# 📂 Chargement des données...
# ✅ Données chargées : 6926 lignes, 16 colonnes
#                            name  company  model           edition  year  \
# 0        Maruti Swift Dzire VDI   Maruti  Swift         Dzire VDI  2014
# 1  Skoda Rapid 1.5 TDI Ambition    Skoda  Rapid  1.5 TDI Ambition  2014
# 2      Honda City 2017-2020 EXi    Honda   City     2017-2020 EXi  2006
# 3     Hyundai i20 Sportz Diesel  Hyundai    i20     Sportz Diesel  2010
# 4        Maruti Swift VXI BSIII   Maruti  Swift         VXI BSIII  2007
#
#     owner    fuel seller_type transmission  km_driven  mileage_mpg  engine_cc  \
# 0   First  Diesel  Individual       Manual     145500        55.00     1248.0
# 1  Second  Diesel  Individual       Manual     120000        49.70     1498.0
# 2   Third  Petrol  Individual       Manual     140000        41.60     1497.0
# 3   First  Diesel  Individual       Manual     127000        54.06     1396.0
# 4   First  Petrol  Individual       Manual     120000        37.84     1298.0
#
#    max_power_bhp   torque_nm  seats  selling_price
# 0          74.00  190.000000    5.0         450000
# 1         103.52  250.000000    5.0         370000
# 2          78.00  124.544455    5.0         158000
# 3          90.00  219.668960    5.0         225000
# 4          88.20  112.776475    5.0         130000
#
# ==================================================
# 📊 INFORMATIONS GÉNÉRALES
# ==================================================
#
# 📋 Colonnes : ['name', 'company', 'model', 'edition', 'year', 'owner', 'fuel', 'seller_type', 'transmission', 'km_driven', 'mileage_mpg', 'engine_cc', 'max_power_bhp', 'torque_nm', 'seats', 'selling_price']
#
# 📏 Dimensions : (6926, 16)
#
# 🔢 Types de données :
# name              object
# company           object
# model             object
# edition           object
# year               int64
# owner             object
# fuel              object
# seller_type       object
# transmission      object
# km_driven          int64
# mileage_mpg      float64
# engine_cc        float64
# max_power_bhp    float64
# torque_nm        float64
# seats            float64
# selling_price      int64
# dtype: object
#
# ❓ Valeurs manquantes :
# name               0
# company            0
# model              0
# edition            0
# year               0
# owner              0
# fuel               0
# seller_type        0
# transmission       0
# km_driven          0
# mileage_mpg      208
# engine_cc        208
# max_power_bhp    209
# torque_nm        209
# seats            208
# selling_price      0
# dtype: int64
#
# 🔁 Doublons : 0
#
# ==================================================
# 📈 STATISTIQUES DESCRIPTIVES
# ==================================================
#               year     km_driven  mileage_mpg    engine_cc  max_power_bhp  \
# count  6926.000000  6.926000e+03  6718.000000  6718.000000    6717.000000
# mean   2013.420300  7.399568e+04    45.080782  1430.891337      87.766100
# std       4.078286  5.835810e+04    10.693383   493.493277      31.724555
# min    1983.000000  1.000000e+00     0.000000   624.000000      32.800000
# 25%    2011.000000  4.000000e+04    38.900000  1197.000000      67.100000
# 50%    2014.000000  7.000000e+04    45.340000  1248.000000      81.830000
# 75%    2017.000000  1.000000e+05    52.440000  1498.000000     100.000000
# max    2020.000000  2.360457e+06    98.700000  3604.000000     400.000000
#
#          torque_nm        seats  selling_price
# count  6717.000000  6718.000000   6.926000e+03
# mean    174.684585     5.434653   5.172707e+05
# std     106.876249     0.984230   5.197670e+05
# min      47.071920     2.000000   2.999900e+04
# 25%     110.000000     5.000000   2.500000e+05
# 50%     160.000000     5.000000   4.000000e+05
# 75%     200.055660     5.000000   6.335000e+05
# max    1863.263500    14.000000   1.000000e+07
#
# 💰 Prix :
#   - Minimum : 29,999.00
#   - Maximum : 10,000,000.00
#   - Moyenne : 517,270.68
#   - Médiane : 400,000.00
#
# ==================================================
# 🏷️  VARIABLES CATÉGORIELLES
# ==================================================
#
# 📊 Distribution de 'name' :
# name
# Maruti Swift Dzire VDI      118
# Maruti Alto 800 LXI          76
# Maruti Alto LXi              69
# Maruti Swift VDI             60
# Maruti Swift VDI BSIV        56
# Maruti Alto K10 VXI          47
# Hyundai EON Era Plus         44
# Maruti Alto LX               43
# Maruti Wagon R VXI BS IV     43
# Maruti Ertiga VDI            42
# Name: count, dtype: int64
#    Nombre de valeurs uniques : 2058
#
# 📊 Distribution de 'company' :
# company
# Maruti        2165
# Hyundai       1267
# Mahindra       723
# Tata           647
# Honda          362
# Ford           361
# Toyota         357
# Chevrolet      216
# Renault        206
# Volkswagen     174
# Name: count, dtype: int64
#    Nombre de valeurs uniques : 32
#
# 📊 Distribution de 'model' :
# model
# Swift      670
# Alto       395
# i20        303
# Wagon      245
# Innova     188
# Bolero     187
# Verna      180
# City       168
# Scorpio    160
# Grand      153
# Name: count, dtype: int64
#    Nombre de valeurs uniques : 207
#
# 📊 Distribution de 'edition' :
# edition
# Dzire VDI      118
# VDI            106
# 800 LXI         76
# LXi             73
# LX              72
# VDI BSIV        56
# VXI             56
# K10 VXI         47
# Era Plus        44
# R VXI BS IV     43
# Name: count, dtype: int64
#    Nombre de valeurs uniques : 1916
#
# 📊 Distribution de 'owner' :
# owner
# First             4242
# Second            1974
# Third              536
# Fourth & Above     169
# Test Drive Car       5
# Name: count, dtype: int64
#    Nombre de valeurs uniques : 5
#
# 📊 Distribution de 'fuel' :
# fuel
# Diesel    3755
# Petrol    3077
# CNG         56
# LPG         38
# Name: count, dtype: int64
#    Nombre de valeurs uniques : 4
#
# 📊 Distribution de 'seller_type' :
# seller_type
# Individual          6218
# Dealer               681
# Trustmark Dealer      27
# Name: count, dtype: int64
#    Nombre de valeurs uniques : 3
#
# 📊 Distribution de 'transmission' :
# transmission
# Manual       6342
# Automatic     584
# Name: count, dtype: int64
#    Nombre de valeurs uniques : 2
#
# ==================================================
# 🔗 CORRÉLATIONS
# ==================================================
#
# Matrice de corrélation :
#                    year  km_driven  mileage_mpg  engine_cc  max_power_bhp  \
# year           1.000000  -0.377003     0.324193  -0.019074       0.159889
# km_driven     -0.377003   1.000000    -0.174163   0.253339       0.041770
# mileage_mpg    0.324193  -0.174163     1.000000  -0.466693      -0.282228
# engine_cc     -0.019074   0.253339    -0.466693   1.000000       0.683506
# max_power_bhp  0.159889   0.041770    -0.282228   0.683506       1.000000
# torque_nm      0.053617   0.128881    -0.160201   0.607003       0.669820
# seats          0.023632   0.207957    -0.380941   0.657798       0.259028
# selling_price  0.433076  -0.165620    -0.067668   0.442857       0.692323
#
#                torque_nm     seats  selling_price
# year            0.053617  0.023632       0.433076
# km_driven       0.128881  0.207957      -0.165620
# mileage_mpg    -0.160201 -0.380941      -0.067668
# engine_cc       0.607003  0.657798       0.442857
# max_power_bhp   0.669820  0.259028       0.692323
# torque_nm       1.000000  0.325996       0.473283
# seats           0.325996  1.000000       0.158111
# selling_price   0.473283  0.158111       1.000000
#
# 💰 Corrélation avec le Prix :
#   - max_power_bhp: 0.6923
#   - torque_nm: 0.4733
#   - engine_cc: 0.4429
#   - year: 0.4331
#   - seats: 0.1581
#   - mileage_mpg: -0.0677
#   - km_driven: -0.1656
#
# ==================================================
# 📊 GÉNÉRATION DES VISUALISATIONS
# ==================================================
# ✅ Graphique sauvegardé : price_distribution.png
# ✅ Graphique sauvegardé : price_by_company.png
# ✅ Graphique sauvegardé : price_vs_kms.png
# ✅ Graphique sauvegardé : price_by_year.png
# ✅ Graphique sauvegardé : fuel_type_distribution.png
#
# 📁 Tous les graphiques sont dans le dossier 'visualizations/'
#
# ==================================================
# ✅ ANALYSE TERMINÉE
# ==================================================
